# %%
# Windows: download installer from https://ollama.com
# Then in terminal:
ollama pull gemma:2b
ollama serve   # starts the HTTP server on localhost:11434
# Out:
#   Cell In[1], line 3
#     ollama pull gemma:2b
#                       ^
# SyntaxError: invalid decimal literal
